# %%
from Base import BaseProcessor


subject = "P5694257"
xdf_filename = f'/Users/bryan.gonzalez/CUNY_subs/sub-{subject}/sub-{subject}_ses-S001_task-CUNY_run-001_mobi.xdf'

events = {
        200: 'Onset_Experiment',
        10: 'Onset_RestingState',
        11: 'Offset_RestingState',
        500: 'Onset_StoryListening',
        501: 'Offset_StoryListening',
        100: 'Onset_10second_rest',
        101: 'Offset_10second_rest', 
        20: 'Onset_CampFriend',
        21: 'Offset_CampFriend',
        30: 'Onset_FrogDissection',
        31: 'Offset_FrogDissection',
        40: 'Onset_DanceContest',
        41: 'Offset_DanceContest',
        50: 'Onset_ZoomClass',
        51: 'Offset_ZoomClass',
        60: 'Onset_Tornado',
        61: 'Offset_Tornado',
        70: 'Onset_BirthdayParty',
        71: 'Offset_BirthdayParty',
        300: 'Onset_subjectInput',
        301: 'Offset_subjectInput',
        302: 'Onset_FavoriteStory',
        303: 'Offset_FavoriteStory',
        304: 'Onset_WorstStory',
        305: 'Offset_WorstStory',
        400: 'Onset_impedanceCheck',
        401: 'Offset_impedanceCheck',
        80: 'Onset_SocialTask',
        81: 'Offset_SocialTask',
        201: 'Offset_Experiment',
    }

# %%
b = BaseProcessor()
b.load_data(xdf_path=xdf_filename, events=events)
# Out:
# Base Processor initialized...
# Loading all streams from /Users/bryan.gonzalez/CUNY_subs/sub-P5694257/sub-P5694257_ses-S001_task-CUNY_run-001_mobi.xdf...

# %%
b.format_data()
# Out:
# Formatting data:   0%|          | 0/6 [00:00<?, ?stream/s]
# Formatting data: 100%|██████████| 6/6 [00:00<00:00, 25.31stream/s]

# %%
b.streams
# Out:
# ['Stimuli_Markers',
#  'Tobii',
#  'WebcamStream',
#  'OpenSignals',
#  'EGI NetAmp 0',
#  'Microphone']

# %%
b.eye_df.head()
# Out:
#    device_time_stamp  left_gaze_origin_validity  right_gaze_origin_validity  \
# 0       2.094710e+10                        1.0                         1.0
# 1       2.094711e+10                        1.0                         1.0
# 2       2.094711e+10                        1.0                         1.0
# 3       2.094712e+10                        1.0                         1.0
# 4       2.094713e+10                        1.0                         1.0
#
#    left_gaze_origin_in_user_coordinate_system_0  \
# 0                                    -29.287296
# 1                                    -29.264740
# 2                                    -29.242916
# 3                                    -29.222673
# 4                                    -29.200703
#
#    left_gaze_origin_in_user_coordinate_system_1  \
# 0                                     65.548798
# 1                                     65.546722
# 2                                     65.548920
# 3                                     65.542946
# 4                                     65.554810
#
#    left_gaze_origin_in_user_coordinate_system_2  \
# 0                                    661.302368
# 1                                    661.256104
# 2                                    661.282593
# 3                                    661.272461
# 4                                    661.310669
#
#    right_gaze_origin_in_user_coordinate_system_0  \
# 0                                      30.935635
# 1                                      30.952454
# 2                                      30.971540
# 3                                      30.994225
# 4                                      31.024431
#
#    right_gaze_origin_in_user_coordinate_system_1  \
# 0                                      68.716370
# 1                                      68.710648
# 2                                      68.706924
# 3                                      68.698532
# 4                                      68.706329
#
#    right_gaze_origin_in_user_coordinate_system_2  \
# 0                                     659.556458
# 1                                     659.531128
# 2                                     659.517273
# 3                                     659.527100
# 4                                     659.596985
#
#    left_gaze_origin_in_trackbox_coordinate_system_0  ...  \
# 0                                          0.558146  ...
# 1                                          0.558104  ...
# 2                                          0.558058  ...
# 3                                          0.558017  ...
# 4                                          0.557969  ...
#
#    right_gaze_point_in_user_coordinate_system_2  \
# 0                                     37.819252
# 1                                     36.886086
# 2                                     39.849648
# 3                                     40.177429
# 4                                     38.663681
#
#    left_gaze_point_on_display_area_0  left_gaze_point_on_display_area_1  \
# 0                           0.465297                           0.538544
# 1                           0.466019                           0.526739
# 2                           0.455663                           0.523538
# 3                           0.462107                           0.528371
# 4                           0.456000                           0.504357
#
#    right_gaze_point_on_display_area_0  right_gaze_point_on_display_area_1  \
# 0                            0.467279                            0.533190
# 1                            0.465837                            0.542763
# 2                            0.469480                            0.512362
# 3                            0.464481                            0.508999
# 4                            0.467998                            0.524528
#
#    left_pupil_validity  right_pupil_validity  left_pupil_diameter  \
# 0                  1.0                   1.0             3.253235
# 1                  1.0                   1.0             3.249542
# 2                  1.0                   1.0             3.227600
# 3                  1.0                   1.0             3.255630
# 4                  1.0                   1.0             3.190369
#
#    right_pupil_diameter    time_stamp
# 0              3.242783  1.134582e+06
# 1              3.200409  1.134582e+06
# 2              3.224915  1.134582e+06
# 3              3.243149  1.134582e+06
# 4              3.244232  1.134582e+06
#
# [5 rows x 32 columns]
