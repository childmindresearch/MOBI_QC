# %%
import Base
import importlib

subject = "P5694257"
xdf_filename = f'/Users/bryan.gonzalez/CUNY_subs/sub-{subject}/sub-{subject}_ses-S001_task-CUNY_run-001_mobi.xdf'

events = {
        200: 'Onset_Experiment',
        10: 'Onset_RestingState',
        11: 'Offset_RestingState',
        500: 'Onset_StoryListening',
        501: 'Offset_StoryListening',
        100: 'Onset_10second_rest',
        101: 'Offset_10second_rest', 
        20: 'Onset_CampFriend',
        21: 'Offset_CampFriend',
        30: 'Onset_FrogDissection',
        31: 'Offset_FrogDissection',
        40: 'Onset_DanceContest',
        41: 'Offset_DanceContest',
        50: 'Onset_ZoomClass',
        51: 'Offset_ZoomClass',
        60: 'Onset_Tornado',
        61: 'Offset_Tornado',
        70: 'Onset_BirthdayParty',
        71: 'Offset_BirthdayParty',
        300: 'Onset_subjectInput',
        301: 'Offset_subjectInput',
        302: 'Onset_FavoriteStory',
        303: 'Offset_FavoriteStory',
        304: 'Onset_WorstStory',
        305: 'Offset_WorstStory',
        400: 'Onset_impedanceCheck',
        401: 'Offset_impedanceCheck',
        80: 'Onset_SocialTask',
        81: 'Offset_SocialTask',
        201: 'Offset_Experiment',
    }

# %%
b = Base.BaseProcessor()
b.load_data(xdf_path=xdf_filename, events=events)
# Out:
# Base Processor initialized...
# Loading all streams from /Users/bryan.gonzalez/CUNY_subs/sub-P5694257/sub-P5694257_ses-S001_task-CUNY_run-001_mobi.xdf...

# %%
importlib.reload(Base)  # Reload the module to ensure any changes are applied

b.format_data()
# Out:
# Formatting data: 100%|██████████| 6/6 [00:00<00:00, 13.67stream/s]

# %%
b.mic.effective_srate
# Out:
# np.float64(44098.88959971951)

# %%
import datetime


datetime.datetime.fromtimestamp(float(b.physio.created_at))
# Out:
# datetime.datetime(1970, 2, 14, 23, 40, 10, 677903)

# %%
b.mic.data.subset(stim_df=b.stim, onset_label="RestingState", offset_label="RestingState")

print(len(b.mic.data))
print(44100*300)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xf/yrxhv1td653c13cnbnjmybcr0000gq/T/ipykernel_7130/903218311.py in ?()
# ----> 1 b.mic.data.subset(stim_df=b.stim, onset_label="RestingState", offset_label="RestingState")
#       2
#       3 print(len(b.mic.data))
#       4 print(44100*300)
#
# ~/MOBI_QC/.venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'subset'

# %%
mm = b.mic
c = b.physio.data
